# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Import Dataset**

# %%
item= r"C:\Users\fahru\Documents\SQL\Export Gcoffee\items25.csv"
menu= r"C:\Users\fahru\Documents\SQL\database\Gcoffee\menu_items.csv"


items= pd.read_csv(item)
items.head()
# Out:
#                          transaction_id  item_id  quantity  unit_price  \
# 0  00001472-e5a0-453f-9575-ecdfa6fe0e6c        3         1         8.0
# 1  00001472-e5a0-453f-9575-ecdfa6fe0e6c        3         3         8.0
# 2  00002670-7a56-485e-9240-0f9ec868b5c8        1         2         6.0
# 3  00002670-7a56-485e-9240-0f9ec868b5c8        2         1         7.0
# 4  00002670-7a56-485e-9240-0f9ec868b5c8        6         2         9.5
#
#    subtotal           created_at
# 0       8.0  2025-05-17 10:17:23
# 1      24.0  2025-05-17 10:17:23
# 2      12.0  2025-04-01 15:21:07
# 3       7.0  2025-04-01 15:21:07
# 4      19.0  2025-04-01 15:21:07

# %%
menus= pd.read_csv(menu)
menus.head()
# Out:
#    item_id   item_name category  price  is_seasonal  available_from  \
# 0        1    Espresso   coffee    6.0        False             NaN
# 1        2   Americano   coffee    7.0        False             NaN
# 2        3       Latte   coffee    8.0        False             NaN
# 3        4  Cappuccino   coffee    8.0        False             NaN
# 4        5  Flat White   coffee    9.0        False             NaN
#
#    available_to
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
trx_detail= items.merge(menus, on='item_id', how='left')
trx_detail.head()
# Out:
#                          transaction_id  item_id  quantity  unit_price  \
# 0  00001472-e5a0-453f-9575-ecdfa6fe0e6c        3         1         8.0
# 1  00001472-e5a0-453f-9575-ecdfa6fe0e6c        3         3         8.0
# 2  00002670-7a56-485e-9240-0f9ec868b5c8        1         2         6.0
# 3  00002670-7a56-485e-9240-0f9ec868b5c8        2         1         7.0
# 4  00002670-7a56-485e-9240-0f9ec868b5c8        6         2         9.5
#
#    subtotal           created_at  item_name category  price  is_seasonal  \
# 0       8.0  2025-05-17 10:17:23      Latte   coffee    8.0        False
# 1      24.0  2025-05-17 10:17:23      Latte   coffee    8.0        False
# 2      12.0  2025-04-01 15:21:07   Espresso   coffee    6.0        False
# 3       7.0  2025-04-01 15:21:07  Americano   coffee    7.0        False
# 4      19.0  2025-04-01 15:21:07      Mocha   coffee    9.5        False
#
#    available_from  available_to
# 0             NaN           NaN
# 1             NaN           NaN
# ...
